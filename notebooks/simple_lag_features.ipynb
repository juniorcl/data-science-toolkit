# %% [markdown]
# # Imports

# %%
import numpy  as np
import pandas as pd

import matplotlib.pyplot as plt

from dstoolkit.feature_engine import SimpleLagTimeFeatureCreator

# %% [markdown]
# ## Loading Dataset

# %%
# the data is from https://datahub.io/core/global-temp
df = pd.read_csv("../data/global_temperature_time_series.csv")

# %%
df.head()
# Out:
#   Source     Year    Mean
# 0   gcag  1850-01 -0.6746
# 1   gcag  1850-02 -0.3334
# 2   gcag  1850-03 -0.5913
# 3   gcag  1850-04 -0.5887
# 4   gcag  1850-05 -0.5088

# %%
df = df.drop(['Source'], axis=1).rename({'Year': 'time', 'Mean': 'temperature'}, axis=1)
df['time'] = pd.to_datetime(df['time'])

# %% [markdown]
# ## Class SimpleLagTimeFeatureCreator

# %%
df = df.loc[:, ['time', 'temperature']].sample(frac=1)
df.head()
# Out:
#            time  temperature
# 1212 1915-07-01      -0.1300
# 1004 1906-11-01      -0.3800
# 33   1852-10-01      -0.1724
# 2004 1948-07-01      -0.1100
# 2052 1950-07-01      -0.0800

# %%
s = SimpleLagTimeFeatureCreator(windows=[2, 3, 4, 5, 6], functions=['mean', 'median', 'max', 'min', 'sum', 'std', 'diff', 'slope'])
df = s.create(df, 'temperature', time='time')

# %%
df.head(10)
# Out:
#         time  temperature  temperature_lag_1  temperature_lag_2  \
# 0 1850-01-01      -0.6746                NaN                NaN
# 1 1850-02-01      -0.3334            -0.6746                NaN
# 2 1850-03-01      -0.5913            -0.3334            -0.6746
# 3 1850-04-01      -0.5887            -0.5913            -0.3334
# 4 1850-05-01      -0.5088            -0.5887            -0.5913
# 5 1850-06-01      -0.3442            -0.5088            -0.5887
# 6 1850-07-01      -0.1598            -0.3442            -0.5088
# 7 1850-08-01      -0.2077            -0.1598            -0.3442
# 8 1850-09-01      -0.3847            -0.2077            -0.1598
# 9 1850-10-01      -0.5331            -0.3847            -0.2077
#
#    temperature_lag_3  temperature_lag_4  temperature_lag_5  temperature_lag_6  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3            -0.6746                NaN                NaN                NaN
# 4            -0.3334            -0.6746                NaN                NaN
# 5            -0.5913            -0.3334            -0.6746                NaN
# 6            -0.5887            -0.5913            -0.3334            -0.6746
# 7            -0.5088            -0.5887            -0.5913            -0.3334
# 8            -0.3442            -0.5088            -0.5887            -0.5913
# 9            -0.1598            -0.3442            -0.5088            -0.5887
#
#    temperature_mean_2_lags  temperature_mean_3_lags  ...  \
# 0                      NaN                      NaN  ...
# 1                      NaN                      NaN  ...
# 2                 -0.50400                      NaN  ...
# 3                 -0.46235                -0.533100  ...
# 4                 -0.59000                -0.504467  ...
# 5                 -0.54875                -0.562933  ...
# 6                 -0.42650                -0.480567  ...
# 7                 -0.25200                -0.337600  ...
# 8                 -0.18375                -0.237233  ...
# 9                 -0.29620                -0.250733  ...
#
#    temperature_diff_lag_2_vs_3  temperature_diff_lag_2_vs_4  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                       0.3412                          NaN
# 4                      -0.2579                       0.0833
# 5                       0.0026                      -0.2553
# 6                       0.0799                       0.0825
# 7                       0.1646                       0.2445
# 8                       0.1844                       0.3490
# 9                      -0.0479                       0.1365
#
#    temperature_diff_lag_2_vs_5  temperature_diff_lag_2_vs_6  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                       0.0859                          NaN
# 6                      -0.1754                       0.1658
# 7                       0.2471                      -0.0108
# 8                       0.4289                       0.4315
# 9                       0.3011                       0.3810
#
#    temperature_diff_lag_3_vs_4  temperature_diff_lag_3_vs_5  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                       0.3412                          NaN
# 5                      -0.2579                       0.0833
# 6                       0.0026                      -0.2553
# 7                       0.0799                       0.0825
# 8                       0.1646                       0.2445
# 9                       0.1844                       0.3490
#
#    temperature_diff_lag_3_vs_6  temperature_diff_lag_4_vs_5  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                       0.3412
# 6                       0.0859                      -0.2579
# 7                      -0.1754                       0.0026
# 8                       0.2471                       0.0799
# 9                       0.4289                       0.1646
#
#    temperature_diff_lag_4_vs_6  temperature_diff_lag_5_vs_6
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                       0.0833                       0.3412
# 7                      -0.2553                      -0.2579
# 8                       0.0825                       0.0026
# 9                       0.2445                       0.0799
#
# [10 rows x 73 columns]

# %%
df.tail(10)
# Out:
#            time  temperature  temperature_lag_1  temperature_lag_2  \
# 3813 2023-11-01       1.3338             1.4200             1.3400
# 3814 2023-12-01       1.3500             1.3338             1.4200
# 3815 2023-12-01       1.2586             1.3500             1.3338
# 3816 2024-01-01       1.1516             1.2586             1.3500
# 3817 2024-02-01       1.2902             1.1516             1.2586
# 3818 2024-03-01       1.2515             1.2902             1.1516
# 3819 2024-04-01       1.2053             1.2515             1.2902
# 3820 2024-05-01       1.0745             1.2053             1.2515
# 3821 2024-06-01       1.1154             1.0745             1.2053
# 3822 2024-07-01       1.1398             1.1154             1.0745
#
#       temperature_lag_3  temperature_lag_4  temperature_lag_5  \
# 3813             1.2866             1.3522             1.4800
# 3814             1.3400             1.2866             1.3522
# 3815             1.4200             1.3400             1.2866
# 3816             1.3338             1.4200             1.3400
# 3817             1.3500             1.3338             1.4200
# 3818             1.2586             1.3500             1.3338
# 3819             1.1516             1.2586             1.3500
# 3820             1.2902             1.1516             1.2586
# 3821             1.2515             1.2902             1.1516
# 3822             1.2053             1.2515             1.2902
#
#       temperature_lag_6  temperature_mean_2_lags  temperature_mean_3_lags  \
# 3813             1.1993                  1.38000                 1.348867
# 3814             1.4800                  1.37690                 1.364600
# 3815             1.3522                  1.34190                 1.367933
# 3816             1.2866                  1.30430                 1.314133
# 3817             1.3400                  1.20510                 1.253400
# 3818             1.4200                  1.22090                 1.233467
# 3819             1.3338                  1.27085                 1.231100
# 3820             1.3500                  1.22840                 1.249000
# 3821             1.2586                  1.13990                 1.177100
# 3822             1.1516                  1.09495                 1.131733
#
#       ...  temperature_diff_lag_2_vs_3  temperature_diff_lag_2_vs_4  \
# 3813  ...                       0.0534                      -0.0122
# 3814  ...                       0.0800                       0.1334
# 3815  ...                      -0.0862                      -0.0062
# 3816  ...                       0.0162                      -0.0700
# 3817  ...                      -0.0914                      -0.0752
# 3818  ...                      -0.1070                      -0.1984
# 3819  ...                       0.1386                       0.0316
# 3820  ...                      -0.0387                       0.0999
# 3821  ...                      -0.0462                      -0.0849
# 3822  ...                      -0.1308                      -0.1770
#
#       temperature_diff_lag_2_vs_5  temperature_diff_lag_2_vs_6  \
# 3813                      -0.1400                       0.1407
# 3814                       0.0678                      -0.0600
# 3815                       0.0472                      -0.0184
# 3816                       0.0100                       0.0634
# 3817                      -0.1614                      -0.0814
# 3818                      -0.1822                      -0.2684
# 3819                      -0.0598                      -0.0436
# 3820                      -0.0071                      -0.0985
# 3821                       0.0537                      -0.0533
# 3822                      -0.2157                      -0.0771
#
#       temperature_diff_lag_3_vs_4  temperature_diff_lag_3_vs_5  \
# 3813                      -0.0656                      -0.1934
# 3814                       0.0534                      -0.0122
# 3815                       0.0800                       0.1334
# 3816                      -0.0862                      -0.0062
# 3817                       0.0162                      -0.0700
# 3818                      -0.0914                      -0.0752
# 3819                      -0.1070                      -0.1984
# 3820                       0.1386                       0.0316
# 3821                      -0.0387                       0.0999
# 3822                      -0.0462                      -0.0849
#
#       temperature_diff_lag_3_vs_6  temperature_diff_lag_4_vs_5  \
# 3813                       0.0873                      -0.1278
# 3814                      -0.1400                      -0.0656
# 3815                       0.0678                       0.0534
# 3816                       0.0472                       0.0800
# 3817                       0.0100                      -0.0862
# 3818                      -0.1614                       0.0162
# 3819                      -0.1822                      -0.0914
# 3820                      -0.0598                      -0.1070
# 3821                      -0.0071                       0.1386
# 3822                       0.0537                      -0.0387
#
#       temperature_diff_lag_4_vs_6  temperature_diff_lag_5_vs_6
# 3813                       0.1529                       0.2807
# 3814                      -0.1934                      -0.1278
# 3815                      -0.0122                      -0.0656
# 3816                       0.1334                       0.0534
# 3817                      -0.0062                       0.0800
# 3818                      -0.0700                      -0.0862
# 3819                      -0.0752                       0.0162
# 3820                      -0.1984                      -0.0914
# 3821                       0.0316                      -0.1070
# 3822                       0.0999                       0.1386
#
# [10 rows x 73 columns]
