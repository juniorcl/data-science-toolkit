# %% [markdown]
# # Imports

# %%
import warnings
import numpy as np
import pandas as pd

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, StratifiedKFold

from dstoolkit.automl.classifier import AutoMLHistGradientBoosting, AutoMLHistGradientBoostingCV

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Functions

# %%
def generate_synthetic_binary_data(
    n_samples=10000,
    n_features=30,
    n_informative=5,
    n_redundant=10,
    n_repeated=0,
    n_classes=2,
    class_sep=0.5,
    flip_y=0.15,
    weights=[0.8, 0.2],
    test_size=0.2,
    valid_size=0.2,
    random_state=42
):
    """
    Gera uma base sintética binária com splits train/valid/test.
    Retorna: (X_train, y_train, X_valid, y_valid, X_test, y_test)
    """

    # ---------------------------
    # 1. Gerar base sintética
    # ---------------------------
    X, y = make_classification(
        n_samples=n_samples,
        n_features=n_features,
        n_informative=n_informative,
        n_redundant=n_redundant,
        n_repeated=n_repeated,
        n_classes=n_classes,
        class_sep=class_sep,
        flip_y=flip_y,
        weights=weights,
        random_state=random_state
    )

    # ---------------------------
    # 2. Train/Test
    # ---------------------------
    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=test_size,
        stratify=y,
        random_state=random_state
    )

    # ---------------------------
    # 3. Train/Validation
    # ---------------------------
    valid_relative = valid_size / (1 - test_size)

    X_train, X_valid, y_train, y_valid = train_test_split(
        X_train, y_train,
        test_size=valid_relative,
        stratify=y_train,
        random_state=random_state
    )

    y_train = pd.DataFrame(y_train, columns=['target'])
    y_valid = pd.DataFrame(y_valid, columns=['target'])
    y_test = pd.DataFrame(y_test, columns=['target'])
    
    return pd.DataFrame(X_train), y_train, pd.DataFrame(X_valid), y_valid, pd.DataFrame(X_test), y_test

# %% [markdown]
# # Data Base

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = generate_synthetic_binary_data(
    n_samples=5000,
    n_features=10,
    n_informative=5,
    n_redundant=5,
    n_repeated=0,
    n_classes=2,
    class_sep=0.5,   # classes mais misturadas
    flip_y=0.15,     # ruído nos rótulos
    weights=[0.8, 0.2],  # desbalanceamento
    test_size=0.2,
    valid_size=0.2,
    random_state=42
)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## HistGradientBoosting

# %%
# %%time
hist = AutoMLHistGradientBoosting(scoring='ks', tune=True, n_trials=20)
hist.train(X_train, y_train, X_valid, y_valid, X_test, y_test)
# Out:
# CPU times: user 1min 25s, sys: 1.28 s, total: 1min 27s
# Wall time: 14.9 s

# %%
hist.get_metrics()
# Out:
#        Balanced Accuracy  Precision    Recall        F1       AUC        KS  \
# Train           1.000000   1.000000  1.000000  1.000000  1.000000  1.000000
# Valid           0.747822   0.783626  0.544715  0.642686  0.810528  0.568868
# Test            0.716714   0.745342  0.487805  0.589681  0.773210  0.469377
#
#               Brier   LogLoss  Avg Precision Lift
# Train  1.210487e-10  0.000007            3.059540
# Valid  1.327923e-01  1.134092            1.921795
# Test   1.537532e-01  1.356074            1.671576

# %%
# %%time
hist.analyze()
# Out:
# CPU times: user 13.3 s, sys: 95.4 ms, total: 13.4 s
# Wall time: 17.5 s

# %% [markdown]
# ## HistGradientBoosting CV

# %%
# %%time
hist_cv = AutoMLHistGradientBoostingCV(scoring='roc_auc', tune=True, n_trials=20, cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42))
hist_cv.train(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 3min 46s, sys: 3.42 s, total: 3min 49s
# Wall time: 39.2 s

# %%
hist_cv.get_metrics()
# Out:
#           Balanced Accuracy  Precision    Recall        F1       AUC  \
# Train CV           0.678002   0.802500  0.386963  0.521861  0.795422
# Test               0.689283   0.846154  0.402439  0.545455  0.801557
#
#                 KS     Brier   LogLoss  Avg Precision Lift
# Train CV  0.481537  0.134986  0.434147            1.652407
# Test      0.498782  0.130671  0.424872            1.769030

# %%
# %%time
hist_cv.analyze()
# Out:
# CPU times: user 2.88 s, sys: 10.9 ms, total: 2.9 s
# Wall time: 3.29 s
